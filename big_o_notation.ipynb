# %%
# importing matplotlib with alias for future use
import matplotlib.pyplot as plt
 # importing for log values
import math

# %%
# set x for all lines except for n^n
x = list(range(1, 4)) 
# separate x range set for n^n plot 
# because it reaches very much higher y values than the other lines and causes them to cluster as a result
# this is alleviated it by giving it a lower max x value so its y value doesnt get as large
x2 = list(range(1, 3))  

# set y values per specified formula
y1 = [n * 0 + 1 for n in x]
# plot both x and y, set line color and label for legend
plt.plot(x, y1, c = 'red', label = '$O(1)$')

# set y values per specified formula
y2 = [math.log(n) for n in x]
# plot both x and y, set line color and label for legend
plt.plot(x, y2, c = 'blue', label = '$O(log n)$') 

# set y values per specified formula
y3 = [n for n in x]
# plot both x and y, set line color and label for legend
plt.plot(x, y3, c = 'green', label = '$O(n)$')

# set y values per specified formula
y4 = [n * math.log(n) for n in x]
# plot both x and y, set line color and label for legend
plt.plot(x, y4, c = 'purple', label = '$O(n log n)$') 

# set y values per specified formula
y5 = [n ** 2 for n in x]
# plot both x and y, set line color and label for legend
plt.plot(x, y5, c = 'orange', label = '$O(n^2)$')

# set y values per specified formula
y6 = [2 ** n for n in x]
# plot both x and y, set line color and label for legend
plt.plot(x, y6, c = 'grey', label = '$O(2^n)$')

# set y values per specified formula
y7 = [math.factorial(n) for n in x]
# plot both x and y, set line color and label for legend 
plt.plot(x, y7, c = 'brown', label = '$O(n!)$')

# set y values per specified formula
y8 = [n ** n for n in x2]
# plot both x and y, set line color and label for legend
plt.plot(x2, y8, c = 'magenta', label = '$O(n^n)$')

# show legend
plt.legend(bbox_to_anchor=(1.03, 1), borderaxespad=0)

# add title
plt.title('Big O Notation')

# add x axis label
plt.xlabel('$Elements$')

# add y axis label
plt.ylabel('$Operations$')

# display
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Bonus Write the code necessary to write your name on a chart. Use box letters.

# use straight lines to write name. only 2 sets of coordinates needed per line.
x1 = [0, 1]
y1 = [1, 1]
plt.plot(x1,y1, c = 'red')

x2 = [1, 1]
y2 = [1, 2]
plt.plot(x2, y2, c = 'blue')

x3 = [1, 0]
y3 = [2, 2]
plt.plot(x3, y3, c = 'orange')

x4 = [0, 0]
y4 = [2, 3]
plt.plot(x4, y4, c = 'purple')

x5 = [0, 1]
y5 = [3, 3]
plt.plot(x5, y5, c = 'green')

x6 = [1.5, 1.5]
y6 = [1, 3]
plt.plot(x6, y6, c = 'brown')

x6 = [1.5, 2.5]
y6 = [3, 3]
plt.plot(x6, y6, c = 'blue')

x6 = [2.5, 2.5]
y6 = [3, 1]
plt.plot(x6, y6, c = 'orange')

x7 = [1.5, 2.5]
y7 = [2, 2]
plt.plot(x7, y7, c = 'green')

x8 = [3, 3]
y8 = [1, 3]
plt.plot(x8, y8, c = 'purple')

x9 = [3, 4]
y9 = [3, 1]
plt.plot(x9, y9, c = 'orange')

x10 = [4, 5]
y10 = [1, 3]
plt.plot(x10, y10, c = 'green')

x11 = [5, 5]
y11 = [3, 1]
plt.plot(x11, y11, c = 'red')

x12 = [5.5, 5.5]
y12 = [1, 3]
plt.plot(x12, y12, c = 'blue')

x13 = [5.5, 6.5]
y13 = [1, 1]
plt.plot(x13, y13, c = 'hotpink')

x14 = [6.5, 6.5]
y14 = [1, 3]
plt.plot(x14, y14, c = 'green')

x15 = [7, 8]
y15 = [1, 1]
plt.plot(x15, y15, c = 'orange')

x16 = [7, 7]
y16 = [1, 3]
plt.plot(x16, y16, c = 'purple')

x17 = [7, 8]
y17 = [2, 2]
plt.plot(x17, y17, c = 'red')

x18 = [7, 8]
y18 = [3, 3]
plt.plot(x18, y18, c = 'green')

x19 = [8.5, 9.5]
y19 = [1, 1]
plt.plot(x19, y19, c = 'blue')

x20 = [8.5, 8.5]
y20 = [1, 3]
plt.plot(x20, y20, c = 'brown')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
